# %%
# !git --version
# Out:
# git version 2.50.1

# %%
# !git clone https://github.com/Natalija-J/genz-personalization-trend-forecasting.git
# Out:
# Cloning into 'genz-personalization-trend-forecasting'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 35 (delta 10), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 16.44 KiB | 155.00 KiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# %cd genz-personalization-trend-forecasting
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting

# %%
# !ls
# Out:
# LICENSE  README.md

# %%
# !git pull origin feature-branch_gen-z-trendpulse
# Out:
# From https://github.com/Natalija-J/genz-personalization-trend-forecasting
#  * branch            feature-branch_gen-z-trendpulse -> FETCH_HEAD
# Updating 6a3dfd9..2a0976d
# Fast-forward
#  gen-z-trendpulse/.gitignore                |  24 ++++
#  gen-z-trendpulse/App.tsx                   | 224 +++++++++++++++++++++++++++++
#  gen-z-trendpulse/README.md                 |  20 +++
#  gen-z-trendpulse/components/TrendCard.tsx  |  77 ++++++++++
#  gen-z-trendpulse/components/TrendChart.tsx |  58 ++++++++
#  gen-z-trendpulse/index.html                |  53 +++++++
#  gen-z-trendpulse/index.tsx                 |  15 ++
#  gen-z-trendpulse/metadata.json             |   5 +
#  gen-z-trendpulse/package.json              |  24 ++++
#  gen-z-trendpulse/services/gemini.ts        | 114 +++++++++++++++
#  gen-z-trendpulse/tsconfig.json             |  29 ++++
#  gen-z-trendpulse/types.ts                  |  28 ++++
#  gen-z-trendpulse/vite.config.ts            |  23 +++
# ...

# %%
# !ls
# Out:
# LICENSE  README.md  gen-z-trendpulse

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 4 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# %cd feature-branch_gen-z-trendpulse
# Out:
# [Errno 2] No such file or directory: 'feature-branch_gen-z-trendpulse'
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting

# %%
# !git branch -a
# Out:
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/feature-branch_gen-z-trendpulse
#   remotes/origin/main

# %%
# !git checkout feature-branch_gen-z-trendpulse
# Out:
# branch 'feature-branch_gen-z-trendpulse' set up to track 'origin/feature-branch_gen-z-trendpulse'.
# Switched to a new branch 'feature-branch_gen-z-trendpulse'

# %%
# !git status
# Out:
# On branch feature-branch_gen-z-trendpulse
# Your branch is up to date with 'origin/feature-branch_gen-z-trendpulse'.
#
# nothing to commit, working tree clean

# %%
# !ls
# Out:
# LICENSE  README.md  gen-z-trendpulse

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !conda env update -f environment.yml
# Out:
# /anaconda/lib/python3.13/argparse.py:1258: FutureWarning: `remote_definition` is deprecated and will be removed in 25.9. Use `conda env create --file=URL` instead.
#   subnamespace, arg_strings = subparser.parse_known_args(arg_strings, None)
# Jupyter detected...
#
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     • https://repo.anaconda.com/pkgs/main
#     • https://repo.anaconda.com/pkgs/r
#
# To accept a channel's Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     ‣ conda tos accept --override-channels --channel CHANNEL
#
# To remove channels with rejected Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     ‣ conda config --remove channels CHANNEL

# %%
# !python script.py
# Out:
# python: can't open file '/mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting/script.py': [Errno 2] No such file or directory

# %%
# !pytest
# Out:
# /bin/bash: line 1: pytest: command not found

# %%
# !cat gemini.ts
# Out:
# cat: gemini.ts: No such file or directory

# %%
# !git status
# Out:
# On branch feature-branch_gen-z-trendpulse
# Your branch is up to date with 'origin/feature-branch_gen-z-trendpulse'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.amlignore
# 	.amlignore.amltmp
# 	gen-z-trendpulse/.amlignore
# 	gen-z-trendpulse/.amlignore.amltmp
# 	gen-z-trendpulse/services/.amlignore
# 	gen-z-trendpulse/services/.amlignore.amltmp
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# %cd services
# Out:
# [Errno 2] No such file or directory: 'services'
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting

# %%
# !cat types.ts
# Out:
# cat: types.ts: No such file or directory

# %%
# !ls
# Out:
# LICENSE  README.md  gen-z-trendpulse

# %%
# %cd gen-z-trendpulse
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting/gen-z-trendpulse

# %%
# !ls
# Out:
# App.tsx     index.html	   package.json   types.ts
# README.md   index.tsx	   services	  vite.config.ts
# components  metadata.json  tsconfig.json

# %%
# !cat types.ts
# Out:
# export enum Category {
#   FASHION = 'Fashion',
#   TECH = 'Tech',
#   LIFESTYLE = 'Lifestyle',
# }
#
# export interface GroundingSource {
#   title: string;
#   uri: string;
# }
#
# export interface TrendItem {
#   id: string;
#   name: string;
#   category: Category;
#   description: string;
#   growthScore: number; // 0 to 100
#   sentiment: 'Positive' | 'Neutral' | 'Mixed';
#   prediction: string;
#   marketStrategy: string; // Actionable insight
#   productIdea: string; // Product dev suggestion
#   sources?: GroundingSource[];
#   historicalData: { month: string; value: number }[]; // For charts
# }
#
# export interface TrendResponse {
#   trends: TrendItem[];
# }

# %%
# %cd services
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting/gen-z-trendpulse/services

# %%
# !cat gemini.ts
# Out:
# import { GoogleGenAI, Type, Schema } from "@google/genai";
# import { Category, TrendItem } from "../types";
#
# const ai = new GoogleGenAI({ apiKey: process.env.API_KEY });
#
# // Schema for the second step (Formatting)
# const trendSchema: Schema = {
#   type: Type.OBJECT,
#   properties: {
#     trends: {
#       type: Type.ARRAY,
#       items: {
#         type: Type.OBJECT,
#         properties: {
#           name: { type: Type.STRING, description: "Name of the trend" },
#           description: { type: Type.STRING, description: "Brief description of the trend" },
#           growthScore: { type: Type.INTEGER, description: "Predicted growth score from 0 to 100" },
#           sentiment: { type: Type.STRING, description: "General sentiment: Positive, Neutral, or Mixed" },
#           prediction: { type: Type.STRING, description: "Future outlook for this trend over the next 6-12 months" },
# ...

# %%
# Out:
# node:internal/modules/esm/get_format:160
#   throw new ERR_UNKNOWN_FILE_EXTENSION(ext, filepath);
#         ^
#
# TypeError [ERR_UNKNOWN_FILE_EXTENSION]: Unknown file extension ".ts" for /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting/gen-z-trendpulse/services/gemini.ts
#     at Object.getFileProtocolModuleFormat [as file:] (node:internal/modules/esm/get_format:160:9)
#     at defaultGetFormat (node:internal/modules/esm/get_format:203:36)
#     at defaultLoad (node:internal/modules/esm/load:143:22)
#     at async ModuleLoader.load (node:internal/modules/esm/loader:553:7)
#     at async ModuleLoader.moduleProvider (node:internal/modules/esm/loader:434:45)
#     at async link (node:internal/modules/esm/module_job:87:21) {
#   code: 'ERR_UNKNOWN_FILE_EXTENSION'
# }
#
# Node.js v20.17.0

# %%
# !node -v
# !npm -v
# Out:
# v20.17.0
# 10.8.2

# %%
# !npm install -g typescript
# Out:
# added 1 package in 2s

# %%
# !node gemini.ts
# Out:
# node:internal/modules/esm/get_format:160
#   throw new ERR_UNKNOWN_FILE_EXTENSION(ext, filepath);
#         ^
#
# TypeError [ERR_UNKNOWN_FILE_EXTENSION]: Unknown file extension ".ts" for /mnt/batch/tasks/shared/LS_root/mounts/clusters/ntjanz1/code/genz-personalization-trend-forecasting/gen-z-trendpulse/services/gemini.ts
#     at Object.getFileProtocolModuleFormat [as file:] (node:internal/modules/esm/get_format:160:9)
#     at defaultGetFormat (node:internal/modules/esm/get_format:203:36)
#     at defaultLoad (node:internal/modules/esm/load:143:22)
#     at async ModuleLoader.load (node:internal/modules/esm/loader:553:7)
#     at async ModuleLoader.moduleProvider (node:internal/modules/esm/loader:434:45)
#     at async link (node:internal/modules/esm/module_job:87:21) {
#   code: 'ERR_UNKNOWN_FILE_EXTENSION'
# }
#
# Node.js v20.17.0

# %%
# !sudo apt-get update
# !sudo apt-get install -y nodejs npm
# !npm install -g typescript ts-node
# Out:
# Get:1 file:/var/cudnn-local-repo-ubuntu2004-9.1.1  InRelease [1572 B]
# Hit:2 http://azure.archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://azure.archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 http://azure.archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:5 http://azure.archive.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://packages.microsoft.com/ubuntu/22.04/prod jammy InRelease [3632 B]
# Get:7 https://nvidia.github.io/libnvidia-container/stable/ubuntu18.04/amd64  InRelease [1484 B]
# Hit:8 https://nvidia.github.io/nvidia-container-runtime/stable/ubuntu18.04/amd64  InRelease
# Hit:9 https://nvidia.github.io/nvidia-docker/ubuntu18.04/amd64  InRelease
# Get:10 https://storage.googleapis.com/tensorflow-serving-apt stable InRelease [3026 B]
# Get:1 file:/var/cudnn-local-repo-ubuntu2004-9.1.1  InRelease [1572 B]
# Get:11 file:/var/nccl-repo-2.2.13-ga-cuda9.2  InRelease
# ...

# %%
# !tsc gemini.ts
# !node gemini.js
# Out:
# gemini.ts:1:43 - error TS2307: Cannot find module '@google/genai' or its corresponding type declarations.
#
# 1 import { GoogleGenAI, Type, Schema } from "@google/genai";
#                                             ~~~~~~~~~~~~~~~
#
# gemini.ts:4:38 - error TS2580: Cannot find name 'process'. Do you need to install type definitions for node? Try `npm i --save-dev @types/node`.
#
# 4 const ai = new GoogleGenAI({ apiKey: process.env.API_KEY });
#                                        ~~~~~~~
#
# gemini.ts:41:56 - error TS2705: An async function or method in ES5 requires the 'Promise' constructor.  Make sure you have a declaration for the 'Promise' constructor or include 'ES2015' in your '--lib' option.
#
# 41 export const fetchTrends = async (category: Category): Promise<TrendItem[]> => {
#                                                           ~~~~~~~~~~~~~~~~~~~~
#
#
# Found 3 errors in the same file, starting at: gemini.ts:1
#
# ...

# %%
# !git checkout main
# Out:
# Switched to branch 'main'
# Your branch is ahead of 'origin/main' by 4 commits.
#   (use "git push" to publish your local commits)

# %%
# !git pull origin main
# Out:
# From https://github.com/Natalija-J/genz-personalization-trend-forecasting
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git checkout -b genz-google-trends-engagement
# Out:
# Switched to a new branch 'genz-google-trends-engagement'

# %%
# !git push -u origin genz-google-trends-engagement
# Out:
# Username for 'https://github.com': ^C

# %%
# !git config --global user.name "Natalija-J"
# !git config --global user.email "ntjanz@gmail.com"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 Natalija-J
#
# NameError: name 'Natalija' is not defined

# %%
# !ssh-keygen -t rsa -b 4096 -C "ntjanz@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/home/azureuser/.ssh/id_rsa):
